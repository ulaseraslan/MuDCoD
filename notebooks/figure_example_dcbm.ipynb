# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../")

# %%
from dypoces.utils.visualization import nxDraw

# %%
viz = nxDraw()

# %%
path = "../figures/n100k2easy.eps"
viz.draw_DCBM(path=path, n=100, k=2, p_in=(0.25,0.25), p_out=(0.1), layout="kamada_kawai", width=0.2, node_size=300, cmap="Set3")

# %%
path = "../figures/n100k2hard.eps"
viz.draw_DCBM(path=path, n=100, k=2, p_in=(0.2,0.2), p_out=(0.1), layout="kamada_kawai", width=0.2, node_size=300, cmap="Set3")

# %%
path = "../figures/n250k5easy.eps"
viz.draw_DCBM(path=path, n=250, k=5, p_in=(0.35,0.35), p_out=(0.1), layout="kamada_kawai", width=0.01, node_size=100, cmap="Set3")

# %%
path = "../figures/n250k5hard.eps"
viz.draw_DCBM(path=path, n=250, k=5, p_in=(0.2,0.2), p_out=(0.1), layout="kamada_kawai", width=0.01, node_size=100, cmap="Set3")
